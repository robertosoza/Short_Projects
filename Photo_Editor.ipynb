# %% [markdown]
# <a href="https://colab.research.google.com/github/robertosoza/Short_Projects/blob/main/Photo_Editor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install rembg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 40.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.4 MB/s eta 0:00:00
# ...

# %%
from rembg import remove
from PIL import Image
input_image = Image.open("/DSC_3846.jpg")
output_image = remove(input_image)
output_image.save("output.png")

# %%
input_image2 = Image.open("/DSC_3849.jpg")
output_image2 = remove(input_image2)
output_image2.save("output2.png")
display(output_image2)
# Out:
# <PIL.Image.Image image mode=RGBA size=2048x1367>
